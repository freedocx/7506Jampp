# %% [markdown]
# # Carga de librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
# %matplotlib inline

# %% [markdown]
# # Carga de datos

# %% [markdown]
# Debido a que se trabajara con grandes cantidades de data se definio cada uno de los tipos de datos de los datos pasados por archivo para no sobrecargar al parser de los archivos csv y ahorrar espacio de memoria al conocer mejor que cantidad de memoria se necesitara.

# %%
data_types_clicks = {'advertiser_id':'category' , 'action_id':'category' , 'source_id':'category', 'created':str,\
                     'countrycode':'category','latitude':np.float16, 'longitude':np.float16, 'wifi_conection':bool,\
                     'carrier_id':np.float32, 'trans_id':str, 'os_minor':'category', 'agent_devise':'category', \
                     'os_major':'category', 'specs_brnad':'category', 'timeToClick': np.float16, 'touchX':np.float16, \
                     'touchY':np.float16, 'ref_type':np.int64, 'ref_hash':np.int64}

data_types_installs = { "created" : str, "application_id" : np.uint8, "ref_type" : 'category',"click_hash" : 'category',\
                       "attributed" : bool, "implicit": bool, "device_countrycode" : 'category',"device_brand" : 'category',\
                       "device_model" : 'category', "session_user_agent" : 'category', "user_agent": 'category',"event_uuid":\
                       'category', "kind" : str, "wifi" : 'category', "trans_id" : str, "ip_address" : 'category', \
                       "device_language" : 'category'}

data_types_events = {'ref_type':'category', 'event_id' : 'category', 'ref_hash': 'category', 'application_id':'category',\
                     'attributed':bool, 'device_os':'category', 'device_os_version':'category', 'device_brand':'category',\
                     'device_model':'category','device_city':'category', 'session_user_agent':'category', 'trans_id':\
                     'category', 'user_agent':'category', 'event_uuid':'category','carrier':'category','kind':'category',\
                     'wifi':"category",'connection_type':'category','ip_address':'category','device_language':'category',\
                     'device_countrycode':'category'}

data_types_auctions = { "auction_type_id" : 'category', "country" : 'category', "date" : str, "device_id" : 'category', \
                      "platform" : 'category', "ref_type_id" : 'category', "source_id" : 'category'}

# %%
clicks = pd.read_csv("/home/anichu/Downloads/tp1/clicks.csv", dtype = data_types_clicks) 
installs =  pd.read_csv("/home/anichu/Downloads/tp1/installs.csv", dtype = data_types_installs)
events = pd.read_csv("/home/anichu/Downloads/tp1/events.csv", dtype = data_types_events)
auctions = pd.read_csv("/home/anichu/Downloads/tp1/auctions.csv", dtype = data_types_auctions)

# %% [markdown]
# # Analisis preliminar

# %%
# Cambiamos el formato de aquellos datos que contengan fecha a datetime para luego trabajar mas comodamente.

clicks['created'] = pd.to_datetime(clicks['created'])
installs['created'] = pd.to_datetime(installs['created'])
auctions['date'] = pd.to_datetime(auctions['date'])

# %% [markdown]
# ## Clicks

# %%
clicks.head()
# Out:
#   advertiser_id action_id source_id                          created  \
# 0             2       NaN         4 2019-03-06 22:42:12.755000+00:00
# 1             0       NaN         0 2019-03-08 10:24:30.641000+00:00
# 2             0       NaN         0 2019-03-08 15:24:16.069000+00:00
# 3             2       NaN         3 2019-03-06 03:08:51.543000+00:00
# 4             2       NaN         3 2019-03-06 03:32:55.570000+00:00
#
#           country_code  latitude  longitude  wifi_connection  carrier_id  \
# 0  6333597102633388268  1.206055   1.070312            False         1.0
# 1  6333597102633388268  1.218750   1.071289            False         4.0
# 2  6333597102633388268  1.206055   1.070312            False         6.0
# 3  6333597102633388268  1.206055   1.070312            False        45.0
# 4  6333597102633388268  1.206055   1.070312            False        45.0
#
#                           trans_id               os_minor  agent_device  \
# 0  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137412412545e+18           NaN
# 1  MMHTOJ6qKAOeIH_Eywh1KIcCaxtO9oM  3.025219449024123e+18           NaN
# 2  vIrEIdf9izUaWdAri6Ezk7T3nHFvNQU   5.97565607170903e+18           NaN
# 3  YaKxxEAs2UmZhSpRfiCO9Zpa82B_AKM  6.768137412412545e+18           NaN
# 4  X5XTOcYQovkl6yadYdAD7xioVGU9jiY  6.768137412412545e+18           NaN
#
#                 os_major          specs_brand  brand  timeToClick    touchX  \
# 0  3.072849339937028e+18  2733035977666442898    NaN     1.563477  0.904785
# 1   1.77408510258909e+18   392184377613098015    NaN          NaN       NaN
# 2  3.072849339937028e+18   392184377613098015    NaN          NaN  0.945801
# 3  3.072849339937028e+18  2733035977666442898    NaN    19.015625  0.035004
# 4  3.072849339937028e+18  2733035977666442898    NaN    28.109375  0.053986
#
#      touchY             ref_type             ref_hash
# 0  0.078003  1891515180541284343  1904083516767779093
# 1       NaN  1891515180541284343  3086509764961796666
# 2  0.472900  1891515180541284343  6958163894863846647
# 3  0.430908  1891515180541284343  4368617728156436525
# 4  0.423096  1891515180541284343  4368617728156436525

# %%
clicks.describe(include='all')
# Out:
#        advertiser_id  action_id source_id                           created  \
# count          26351        0.0     26351                             26351
# unique             7        0.0        11                             26347
# top                3        NaN         0  2019-03-10 05:02:10.703000+00:00
# freq           26263        NaN     17009                                 2
# first            NaN        NaN       NaN  2019-03-05 01:17:30.663000+00:00
# last             NaN        NaN       NaN  2019-03-13 23:59:59.298000+00:00
# mean             NaN        NaN       NaN                               NaN
# std              NaN        NaN       NaN                               NaN
# min              NaN        NaN       NaN                               NaN
# 25%              NaN        NaN       NaN                               NaN
# 50%              NaN        NaN       NaN                               NaN
# 75%              NaN        NaN       NaN                               NaN
# max              NaN        NaN       NaN                               NaN
#
#         country_code      latitude     longitude wifi_connection  \
# count   2.635100e+04  26351.000000  26351.000000           26351
# unique           NaN           NaN           NaN               1
# top              NaN           NaN           NaN           False
# freq             NaN           NaN           NaN           26351
# first            NaN           NaN           NaN             NaN
# last             NaN           NaN           NaN             NaN
# mean    6.333597e+18      1.207031      1.070312             NaN
# std     2.089000e+05      0.004375      0.001891             NaN
# min     6.333597e+18      1.205078      1.058594             NaN
# 25%     6.333597e+18      1.206055      1.070312             NaN
# 50%     6.333597e+18      1.206055      1.070312             NaN
# 75%     6.333597e+18      1.206055      1.070312             NaN
# max     6.333597e+18      1.238281      1.084961             NaN
#
#           carrier_id                         trans_id                os_minor  \
# count   26340.000000                            26351                   26339
# unique           NaN                            26351                      28
# top              NaN  M2Flj35pZI10q2ZGeHjcWAskzUgSitw  3.3786399484966047e+18
# freq             NaN                                1                    6922
# first            NaN                              NaN                     NaN
# last             NaN                              NaN                     NaN
# mean        7.743812                              NaN                     NaN
# std         7.016973                              NaN                     NaN
# min         0.000000                              NaN                     NaN
# 25%         3.000000                              NaN                     NaN
# 50%         6.000000                              NaN                     NaN
# 75%        13.000000                              NaN                     NaN
# max       116.000000                              NaN                     NaN
#
#         agent_device               os_major   specs_brand        brand  \
# count   3.243000e+03                  26339  2.635100e+04  6235.000000
# unique           NaN                     12           NaN          NaN
# top              NaN  3.072849339937028e+18           NaN          NaN
# freq             NaN                   7430           NaN          NaN
# first            NaN                    NaN           NaN          NaN
# last             NaN                    NaN           NaN          NaN
# mean    4.171028e+18                    NaN  1.299055e+18     1.482277
# std     2.460496e+18                    NaN  1.149672e+18     1.583764
# min     4.513618e+16                    NaN  3.921844e+17     0.000000
# 25%     1.975183e+18                    NaN  3.921844e+17     0.000000
# 50%     3.516812e+18                    NaN  3.921844e+17     1.000000
# 75%     6.589622e+18                    NaN  2.733036e+18     2.000000
# max     9.221733e+18                    NaN  8.930605e+18    13.000000
#
#          timeToClick        touchX        touchY      ref_type      ref_hash
# count   2.297700e+04  23011.000000  23011.000000  2.635100e+04  2.635100e+04
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# first            NaN           NaN           NaN           NaN           NaN
# last             NaN           NaN           NaN           NaN           NaN
# mean             inf      0.639160      1.478516  1.888100e+18  4.611581e+18
# std              inf      0.302002      2.623047  1.721252e+17  2.673175e+18
# min     1.699829e-02      0.000000      0.000000  1.494519e+18  9.286192e+14
# 25%     2.914062e+00      0.426025      0.182983  1.891515e+18  2.273798e+18
# 50%     1.058594e+01      0.726074      0.645020  1.891515e+18  4.623721e+18
# 75%     7.168750e+01      0.900879      0.991211  1.891515e+18  6.917850e+18
# max     1.761600e+04      1.000000     16.593750  6.323872e+18  9.221118e+18

# %%
# Notamos todos los valores de action_id nos nulos por lo que quitamos tal columna
del clicks['action_id']

# %%
#Notamos que todos los clicks se realizaron sin wi-fi
clicks['wifi_connection'].value_counts()
# Out:
# False    26351
# Name: wifi_connection, dtype: int64

# %%
# Notamos que todos los clicks realiados se realizaron sin wi-fi, luego borramos tal columna
wifi_connection = False
del clicks['wifi_connection']

# %%
# Notamos que todos los clicks se realizaron en el mismo pais
clicks['country_code'].value_counts()
# Out:
# 6333597102633388268    26351
# Name: country_code, dtype: int64

# %%
# Luego nos guardamos el dato del pais y eliminamos tal columna
country_code = 6333597102633388268
del clicks['country_code']

# %%
clicks.head()
# Out:
#   advertiser_id source_id                          created  latitude  \
# 0             2         4 2019-03-06 22:42:12.755000+00:00  1.206055
# 1             0         0 2019-03-08 10:24:30.641000+00:00  1.218750
# 2             0         0 2019-03-08 15:24:16.069000+00:00  1.206055
# 3             2         3 2019-03-06 03:08:51.543000+00:00  1.206055
# 4             2         3 2019-03-06 03:32:55.570000+00:00  1.206055
#
#    longitude  carrier_id                         trans_id  \
# 0   1.070312         1.0  iGgClCM9exiHF4K31g94XmvHEBSLKIY
# 1   1.071289         4.0  MMHTOJ6qKAOeIH_Eywh1KIcCaxtO9oM
# 2   1.070312         6.0  vIrEIdf9izUaWdAri6Ezk7T3nHFvNQU
# 3   1.070312        45.0  YaKxxEAs2UmZhSpRfiCO9Zpa82B_AKM
# 4   1.070312        45.0  X5XTOcYQovkl6yadYdAD7xioVGU9jiY
#
#                 os_minor  agent_device               os_major  \
# 0  6.768137412412545e+18           NaN  3.072849339937028e+18
# 1  3.025219449024123e+18           NaN   1.77408510258909e+18
# 2   5.97565607170903e+18           NaN  3.072849339937028e+18
# 3  6.768137412412545e+18           NaN  3.072849339937028e+18
# 4  6.768137412412545e+18           NaN  3.072849339937028e+18
#
#            specs_brand  brand  timeToClick    touchX    touchY  \
# 0  2733035977666442898    NaN     1.563477  0.904785  0.078003
# 1   392184377613098015    NaN          NaN       NaN       NaN
# 2   392184377613098015    NaN          NaN  0.945801  0.472900
# 3  2733035977666442898    NaN    19.015625  0.035004  0.430908
# 4  2733035977666442898    NaN    28.109375  0.053986  0.423096
#
#               ref_type             ref_hash
# 0  1891515180541284343  1904083516767779093
# 1  1891515180541284343  3086509764961796666
# 2  1891515180541284343  6958163894863846647
# 3  1891515180541284343  4368617728156436525
# 4  1891515180541284343  4368617728156436525

# %% [markdown]
# ## Installs

# %%
installs.head()
# Out:
#                   created  application_id             ref_type  \
# 0 2019-03-13 01:43:33.445               0  1891515180541284343
# 1 2019-03-13 04:58:35.078               0  1891515180541284343
# 2 2019-03-13 04:20:57.666               0  1891515180541284343
# 3 2019-03-13 04:20:57.698               0  1891515180541284343
# 4 2019-03-10 22:24:56.684               0  1891515180541284343
#
#               ref_hash click_hash  attributed  implicit   device_countrycode  \
# 0  8464844987297247076        NaN       False     False  6333597102633388268
# 1  3250564871270161533        NaN       False     False  6333597102633388268
# 2  7953318831018100268        NaN       False      True  6333597102633388268
# 3  7953318831018100268        NaN       False     False  6333597102633388268
# 4  8355110941557237501        NaN       False      True  6333597102633388268
#
#              device_brand            device_model  \
# 0   3.083058605577787e+17  4.4452523127597215e+18
# 1   3.083058605577787e+17  4.4452523127597215e+18
# 2  5.1379920467642125e+17   6.026543327929208e+18
# 3  5.1379920467642125e+17   6.026543327929208e+18
# 4   1.083368711068078e+18   7.876611839898798e+18
#
#                   session_user_agent user_agent  \
# 0                                NaN        NaN
# 1                                NaN        NaN
# 2  HasOffers Mobile AppTracking v1.0        NaN
# 3                                NaN        NaN
# 4  HasOffers Mobile AppTracking v1.0        NaN
#
#                              event_uuid  kind wifi trans_id  \
# 0                                   NaN   NaN  NaN      NaN
# 1                                   NaN   NaN  NaN      NaN
# 2  0bfa9b4c-e07a-4522-b32d-138e3165ac98  Open  NaN      NaN
# 3                                   NaN   NaN  NaN      NaN
# 4  8f235a8c-41bf-4399-b33d-c41577c949b0  Open  NaN      NaN
#
#             ip_address         device_language
# 0  5529284367937637301                     NaN
# 1  6098022721363533304                     NaN
# 2  4636407223847323867  3.3013777759776993e+18
# 3  4636407223847323867                     NaN
# 4   685400811232710215  3.3013777759776993e+18

# %%
installs.describe(include='all')
# Out:
#                            created  application_id             ref_type  \
# count                         3412     3412.000000                 3412
# unique                        3412             NaN                    2
# top     2019-03-09 04:34:41.291000             NaN  1891515180541284343
# freq                             1             NaN                 2080
# first   2019-03-05 00:00:38.219000             NaN                  NaN
# last    2019-03-13 23:54:00.526000             NaN                  NaN
# mean                           NaN       10.247655                  NaN
# std                            NaN        6.016194                  NaN
# min                            NaN        0.000000                  NaN
# 25%                            NaN        7.000000                  NaN
# 50%                            NaN        9.000000                  NaN
# 75%                            NaN       10.000000                  NaN
# max                            NaN       36.000000                  NaN
#
#             ref_hash attributed implicit           device_brand  \
# count   3.412000e+03       3412     3412                   1047
# unique           NaN          1        2                     27
# top              NaN      False    False  3.083058605577787e+17
# freq             NaN       3412     2547                    472
# first            NaN        NaN      NaN                    NaN
# last             NaN        NaN      NaN                    NaN
# mean    4.598202e+18        NaN      NaN                    NaN
# std     2.663828e+18        NaN      NaN                    NaN
# min     4.958527e+15        NaN      NaN                    NaN
# 25%     2.268353e+18        NaN      NaN                    NaN
# 50%     4.603807e+18        NaN      NaN                    NaN
# 75%     6.912404e+18        NaN      NaN                    NaN
# max     9.218934e+18        NaN      NaN                    NaN
#
#                 device_model session_user_agent  \
# count                   3411               3364
# unique                   415                 12
# top     2.33194661091417e+18       http-kit/2.0
# freq                     759               1729
# first                    NaN                NaN
# last                     NaN                NaN
# mean                     NaN                NaN
# std                      NaN                NaN
# min                      NaN                NaN
# 25%                      NaN                NaN
# 50%                      NaN                NaN
# 75%                      NaN                NaN
# max                      NaN                NaN
#
#                                               user_agent  \
# count                                               1729
# unique                                               334
# top     MercadoPago/2.58.0.2 CFNetwork/976 Darwin/18.2.0
# freq                                                 393
# first                                                NaN
# last                                                 NaN
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#                                   event_uuid           kind  wifi  \
# count                                    865            865  1729
# unique                                   865             20     2
# top     ffc389df-f154-4b88-b5f3-d61498e4f801  af_app_opened  true
# freq                                       1            428  1377
# first                                    NaN            NaN   NaN
# last                                     NaN            NaN   NaN
# mean                                     NaN            NaN   NaN
# std                                      NaN            NaN   NaN
# min                                      NaN            NaN   NaN
# 25%                                      NaN            NaN   NaN
# 50%                                      NaN            NaN   NaN
# 75%                                      NaN            NaN   NaN
# max                                      NaN            NaN   NaN
#
#                  ip_address         device_language
# count                  3412                    3378
# unique                 2717                      30
# top     1992632945768888579  3.3013777759776993e+18
# freq                     33                    1484
# first                   NaN                     NaN
# last                    NaN                     NaN
# mean                    NaN                     NaN
# std                     NaN                     NaN
# min                     NaN                     NaN
# 25%                     NaN                     NaN
# 50%                     NaN                     NaN
# 75%                     NaN                     NaN
# max                     NaN                     NaN

# %%
# Notamos todos los valores de action_id y trans_id nos nulos por lo que quitamos tal columna
del installs['click_hash']
del installs['trans_id']

# Notamos que todos los installs se realizaron en el mismo pais
installs['device_countrycode'].value_counts()
del installs['device_countrycode']

#Notamos que ninguno de los installs fueron atribuidos a Jammp
attributed = False
del installs['attributed']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'click_hash'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-88-d4214c53529d> in <module>
#       1 # Notamos todos los valores de action_id y trans_id nos nulos por lo que quitamos tal columna
# ----> 2 del installs['click_hash']
#       3 del installs['trans_id']
#       4
#       5 # Notamos que todos los installs se realizaron en el mismo pais
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    3313             # there was no match, this call should raise the appropriate
#    3314             # exception:
# -> 3315             self._data.delete(key)
#    3316
#    3317         # delete from the caches
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals/managers.py in delete(self, item)
#     983         Delete selected item (items if non-unique) in-place.
#     984         """
# --> 985         indexer = self.items.get_loc(item)
#     986
#     987         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'click_hash'

# %% [markdown]
# ## Events

# %%
events.head()
# Out:
#                       date event_id             ref_type             ref_hash  \
# 0  2019-03-05 00:09:36.966        0  1891515180541284343  2688759737656491380
# 1  2019-03-05 00:09:38.920        1  1891515180541284343  2688759737656491380
# 2  2019-03-05 00:09:26.195        0  1891515180541284343  2688759737656491380
# 3  2019-03-05 00:09:31.107        2  1891515180541284343  2688759737656491380
# 4  2019-03-09 21:00:36.585        3  1891515180541284343  2635154697734164782
#
#   application_id  attributed   device_countrycode      device_os_version  \
# 0             38       False  6333597102633388268  5.908703034097298e+17
# 1             38       False  6333597102633388268  5.908703034097298e+17
# 2             38       False  6333597102633388268  5.908703034097298e+17
# 3             38       False  6333597102633388268  5.908703034097298e+17
# 4             38       False  6333597102633388268  7.391843585977942e+18
#
#   device_brand           device_model  ... trans_id user_agent  \
# 0          NaN  5.990116681709081e+18  ...      NaN        NaN
# 1          NaN  5.990116681709081e+18  ...      NaN        NaN
# 2          NaN  5.990116681709081e+18  ...      NaN        NaN
# 3          NaN  5.990116681709081e+18  ...      NaN        NaN
# 4          NaN  5.960895846746644e+18  ...      NaN        NaN
#
#                              event_uuid                 carrier  \
# 0  a9c0b263-acb2-4577-92c5-cbde5d7a5db1  2.2481569642543155e+17
# 1  1cd98205-0d97-4ec2-a019-667997dbfe7a  2.2481569642543155e+17
# 2  f02e2924-21ae-492b-b625-9021ae0a4eca  2.2481569642543155e+17
# 3  a813cf45-a36e-4668-85e2-5395f1564e98  2.2481569642543155e+17
# 4  63a4f0aa-e147-469f-8c55-4ca4f8d0e310  2.2481569642543155e+17
#
#                     kind              device_os wifi connection_type  \
# 0  5.516623012570946e+18  7.531669329342818e+18  NaN       Cable/DSL
# 1  9.977660181316936e+17  7.531669329342818e+18  NaN       Cable/DSL
# 2  5.516623012570946e+18  7.531669329342818e+18  NaN       Cable/DSL
# 3  8.561152834701074e+18  7.531669329342818e+18  NaN       Cable/DSL
# 4  8.731901657619553e+17  7.531669329342818e+18  NaN       Cable/DSL
#
#             ip_address         device_language
# 0  7858558567428669000   4.077062198952597e+17
# 1  7858558567428669000   4.077062198952597e+17
# 2  7858558567428669000   4.077062198952597e+17
# 3  6324037615828123965   4.077062198952597e+17
# 4  2894495631302821483  3.3013777759776993e+18
#
# [5 rows x 22 columns]

# %%
events.describe(include='all')
# Out:
#                            date event_id             ref_type  \
# count                   2494423  2494423              2494423
# unique                  2488829      568                    2
# top     2019-03-12 14:36:58.017       22  1891515180541284343
# freq                          3   618228              1882743
#
#                    ref_hash application_id attributed   device_countrycode  \
# count               2494423        2494423    2494423              2494423
# unique               196049            269          2                    1
# top     7823950631004872496             66      False  6333597102633388268
# freq                   2913         325696    2489324              2494423
#
#              device_os_version           device_brand          device_model  \
# count                  1022066                1164963               2406456
# unique                      81                    250                  2624
# top     4.3537503246500966e+18  3.083058605577787e+17  2.33194661091417e+18
# freq                    277691                 579861                210697
#
#         ... trans_id             user_agent  \
# count   ...       82                1391527
# unique  ...       13                   5111
# top     ...   {hash}  2.394269162455642e+18
# freq    ...       33                  42325
#
#                                   event_uuid                 carrier  \
# count                                2489324                  616434
# unique                               2489324                      84
# top     fffe3715-a834-4e1f-8857-d54ede5c8721  2.2481569642543155e+17
# freq                                       1                  436983
#
#                          kind              device_os     wifi connection_type  \
# count                 2489324                 657667  1378872          612463
# unique                    583                      4        2               3
# top     5.500848327478996e+18  7.531669329342818e+18     true       Cable/DSL
# freq                   618217                 389811   930902          331948
#
#                  ip_address        device_language
# count               2494423                2406604
# unique               285212                    186
# top     1992632945768888579  6.977049253562486e+18
# freq                  22640                 745898
#
# [4 rows x 22 columns]

# %%
del events['device_countrycode']

# %% [markdown]
# ## Auctions

# %%
auctions.head()
# Out:
#   auction_type_id              country                       date  \
# 0             NaN  6333597102633388268 2019-03-11 14:18:33.290763
# 1             NaN  6333597102633388268 2019-03-11 14:18:34.440157
# 2             NaN  6333597102633388268 2019-03-11 14:18:35.862360
# 3             NaN  6333597102633388268 2019-03-11 14:18:36.167163
# 4             NaN  6333597102633388268 2019-03-11 14:18:37.728590
#
#              device_id platform ref_type_id source_id
# 0  6059599345986491085        1           1         0
# 1  1115994996230693426        1           1         0
# 2  7463856250762200923        1           1         0
# 3  7829815350267792040        1           1         0
# 4  1448534231953777480        1           1         0

# %%
auctions.describe(include='all')
# Out:
#         auction_type_id              country                        date  \
# count               0.0             19571319                    19571319
# unique              0.0                    1                    19570963
# top                 NaN  6333597102633388268  2019-03-13 18:19:02.095780
# freq                NaN             19571319                           2
# first               NaN                  NaN  2019-03-05 00:52:33.352526
# last                NaN                  NaN  2019-03-13 23:59:59.997032
#
#                  device_id  platform ref_type_id source_id
# count             19571319  19571319    19571319  19571319
# unique              206977         2           2         5
# top     633139769114048761         1           1         0
# freq                 27762  15541825    15541825  13354597
# first                  NaN       NaN         NaN       NaN
# last                   NaN       NaN         NaN       NaN

# %%
auctions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19571319 entries, 0 to 19571318
# Data columns (total 7 columns):
# auction_type_id    category
# country            category
# date               datetime64[ns]
# device_id          category
# platform           category
# ref_type_id        category
# source_id          category
# dtypes: category(6), datetime64[ns](1)
# memory usage: 328.9 MB

# %%
auctions.isnull()['auction_type_id'].value_counts()|
# Out:
#   File "<ipython-input-95-6088fe4427b1>", line 1
#     auctions.isnull()['auction_type_id'].value_counts()|
#                                                         ^
# SyntaxError: invalid syntax

# %%
# Notamos que todos los datos de auction_type_id son invalidos por lo que borramos tal columna
del auctions['auction_type_id']

# %%
# Notamos que como en los otros archivos, los datos corresponden a los de un mismo pais, luego borramos tal dato.
del auctions['country']

# %%
auctions.head()

# %% [markdown]
# # Analisis de datos

# %% [markdown]
# ## Auctions

# %% [markdown]
# ### Posicion de clickeo en la pantallade una publicidad

# %%
# Para poder graficar, borramos todos los valores invalidos de touchX y touchY que son aproximadamente un 15% de los datos.
positions = (clicks[['touchX', 'touchY']]).dropna()

# %%
positions.describe()
# Out:
#              touchX        touchY
# count  23011.000000  23011.000000
# mean       0.638672      1.478516
# std        0.302002      2.623047
# min        0.000000      0.000000
# 25%        0.426025      0.182983
# 50%        0.726074      0.645020
# 75%        0.900879      0.991211
# max        1.000000     16.593750

# %%
# Notamos que el valor maximo de touchY es mucho mayor al valor promedio de los valores.

#Analizaremos el porcentaje de los valores de 'touchY' que sean mayores que 3.
positions["touchY"].apply(lambda x: x>3).mean()*100
# Out:
# 10.564512624397029

# %%
# Tomaremos para lograr una mejor representacion los valoresde touchY menores a 3.
positions = positions[positions.touchY<3]

# %%
# Grafico
f, ax = plt.subplots()

ax = sns.kdeplot(positions['touchX'], positions['touchY'], cmap="Reds", shade=True, bw=.60, shade_lowest=True)

ax.set_xlabel('posicion X')
ax.set_ylabel('posicion Y')
ax.set_title('Posicion de clicks en publicidad', fontdict={'color':'darkred','size': 16})

axispos = plt.axis([0,1,0,3])

# %% [markdown]
# ### Tiempo que se tarda en clickear una publicidad

# %%
# Quitamos los valores invalidos
time = clicks['timeToClick'].dropna()

# %%
# Acotaremos nuestro analisis al primer minuto de aparicion de una publicidad.
time = time[time<=60]

# %%
# Grafico
f, ax = plt.subplots(figsize=(25, 5))

plt.title('Distribucion de cantidad de clicks en el primer minuto de aparicion de publicidad', fontdict={'color':'b','size': 16})
plt.xlabel('segundos')
ax.set_yticklabels([])

ax= plt.hist(time, bins= range(60), alpha=0.75)

# %% [markdown]
# ### Dia de la semana en la que se realizan mayor cantidad de click

# %%
# Función para convertir fecha a día de la semana.
def fecha_a_dia(fecha):
    return fecha.weekday()

# Se crean columnas con los dias de la semana.
clicks['weekday'] = clicks['created'].map(fecha_a_dia)

# %%
# Se cuenta la cantidad de clicks por dia de semana y se ordenan de manera convencional.
weekdays = clicks['weekday'].sort_index()

# %%
weekdays_labels = ['Domingo','Lunes','Martes','Miercoles','Jueves','Viernes','Sabado']

'''plt.style.use('fivethirtyeight')
fig, ax = plt.subplots()
ax.plot(clicks['weekday'].value_counts())

ax.set_xlabel('day of the week')
plt.xticks(labels = weekdays_labels)
ax.set_ylabel('clicks')'''
days = [0,1,2,3,4,5,6]

eating = [2,2,2,2,2,3,3]
sleeping= [7,7,7,6,6,10,10]
working= [8,8,10,8,8,0,0] 
playing = [7,7,5,8,7,11,11]

plt.plot([ ], [ ], label='sleeping')
plt.plot([ ], [ ], label='’eating’')
plt.plot([ ], [ ],  label='’working’')
plt.plot([ ], [ ], label='’playing’')

plt.stackplot(days, sleeping, eating, working, playing)
# Out:
# [<matplotlib.collections.PolyCollection at 0x7fb3a89c5470>,
#  <matplotlib.collections.PolyCollection at 0x7fb3a89c56a0>,
#  <matplotlib.collections.PolyCollection at 0x7fb3a89c5908>,
#  <matplotlib.collections.PolyCollection at 0x7fb3a89c5b70>]
